# %%
import intake

# %%
def make_rename_map(ds,model,coord_rename_map = {}):
    
    coord_rename_map[model] = {}
    
    if ('latitude' in ds.coords):
        coord_rename_map[model]['latitude'] = 'latitude'
    elif ('lat' in ds.coords) and ('latitude' not in ds.data_vars):
        coord_rename_map[model]['lat'] = 'latitude'
    elif ('lat' not in ds.coords) and ('latitude' not in ds.coords):
        if 'latitude' in ds.data_vars:
            coord_rename_map[model]['latitude'] = 'latitude'
        elif 'lat' in ds.data_vars:
            coord_rename_map[model]['lat'] = 'latitude'
        elif 'nav_lat' in ds.data_vars:
            coord_rename_map[model]['nav_lat'] = 'latitude'
#         elif 'lat_bnds' in ds.data_vars:
#             coord_rename_map[model]['lat_bnds'] = 'latitude'

    if ('longitude' in ds.coords):
        coord_rename_map[model]['longitude'] = 'longitude'
    elif ('lon' in ds.coords) and ('longitude' not in ds.data_vars):
        coord_rename_map[model]['lon'] = 'longitude'
    elif ('lon' not in ds.coords) and ('longitude' not in ds.coords):
        if 'longitude' in ds.data_vars:
            coord_rename_map[model]['longitude'] = 'longitude'
        elif 'lon' in ds.data_vars:
            coord_rename_map[model]['lon'] = 'longitude'
        elif 'nav_lon' in ds.data_vars:
            coord_rename_map[model]['nav_lon'] = 'longitude'
#         elif 'lon_bnds' in ds.data_vars:
#             coord_rename_map[model]['lon_bnds'] = 'longitude'
    
    if ('lev' in ds.coords):
        coord_rename_map[model]['lev'] = 'lev'
    elif ('lev' not in ds.coords):
        if 'olevel' in ds.coords:
            coord_rename_map[model]['olevel'] = 'lev'
        elif 'depth' in ds.coords:
            coord_rename_map[model]['depth'] = 'lev'
        elif 'rho' in ds.coords:
            coord_rename_map[model]['rho'] = 'lev'
    
    return coord_rename_map

# %% [markdown]
# # Load the CMIP6 catalog

# %%
col = intake.open_esm_datastore('../catalogs/pangeo-cmip6.json')
cat = col.search(experiment_id='historical',
                 table_id='Omon',
                 variable_id='thetao',
                 grid_label='gn')

# dictionary of subset data
dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True},
                                cdf_kwargs={'chunks': {}})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 22 group(s)

# %%
# an example of how a single model is called
ds = dset_dict[f'CMIP.NCAR.CESM2.historical.Omon.gn']
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (d2: 2, lev: 60, member_id: 11, nlat: 384, nlon: 320, time: 1980, vertices: 4)
# Coordinates:
#   * time       (time) object 1850-01-15 13:00:00 ... 2014-12-15 12:00:00
#   * lev        (lev) float64 500.0 1.5e+03 2.5e+03 ... 5.125e+05 5.375e+05
#   * nlon       (nlon) int32 1 2 3 4 5 6 7 8 ... 313 314 315 316 317 318 319 320
#   * nlat       (nlat) int32 1 2 3 4 5 6 7 8 ... 377 378 379 380 381 382 383 384
#   * member_id  (member_id) <U9 'r10i1p1f1' 'r11i1p1f1' ... 'r8i1p1f1' 'r9i1p1f1'
# Dimensions without coordinates: d2, vertices
# Data variables:
#     lon_bnds   (nlat, nlon, vertices) float32 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
#     lon        (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     lat_bnds   (nlat, nlon, vertices) float32 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
#     lat        (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     time_bnds  (time, d2) object dask.array<chunksize=(1980, 2), meta=np.ndarray>
#     lev_bnds   (lev, d2) float32 dask.array<chunksize=(60, 2), meta=np.ndarray>
#     thetao     (member_id, time, lev, nlat, nlon) float32 dask.array<chunksize=(1, 8, 60, 384, 320), meta=np.ndarray>
# Attributes:
#     physics_index:          1
#     license:                CMIP6 model data produced by <The National Center...
#     nominal_resolution:     100 km
#     activity_id:            CMIP
#     branch_method:          standard
#     external_variables:     areacello volcello
#     institution:            National Center for Atmospheric Research, Climate...
#     parent_mip_era:         CMIP6
#     table_id:               Omon
#     branch_time_in_parent:  295650.0
#     parent_activity_id:     CMIP
#     parent_variant_label:   r1i1p1f1
#     variant_info:           CMIP6 20th century experiments (1850-2014) with C...
#     forcing_index:          1
#     creation_date:          2019-01-27T09:14:57Z
#     realization_index:      9
#     Conventions:            CF-1.7 CMIP-6.2
#     realm:                  ocean
#     sub_experiment:         none
#     variable_id:            thetao
#     cesm_casename:          b.e21.BHIST.f09_g17.CMIP6-historical.009
#     parent_time_units:      days since 0001-01-01 00:00:00
#     case_id:                23
#     sub_experiment_id:      none
#     initialization_index:   1
#     parent_source_id:       CESM2
#     source_type:            AOGCM BGC
#     further_info_url:       https://furtherinfo.es-doc.org/CMIP6.NCAR.CESM2.h...
#     source_id:              CESM2
#     parent_experiment_id:   piControl
#     mip_era:                CMIP6
#     model_doi_url:          https://doi.org/10.5065/D67H1H0V
#     experiment_id:          historical
#     source:                 CESM2 (2017): atmosphere: CAM6 (0.9x1.25 finite v...
#     branch_time_in_child:   674885.0
#     grid:                   native gx1v7 displaced pole grid (384x320 latxlon)
#     experiment:             all-forcing simulation of the recent past
#     contact:                cesm_cmip6@ucar.edu
#     product:                model-output
#     data_specs_version:     01.00.29
#     tracking_id:            hdl:21.14100/19f9ed4d-daf4-4a51-8563-fe32b9c2a0cd...
#     frequency:              mon
#     variant_label:          r9i1p1f1
#     grid_label:             gn
#     institution_id:         NCAR

# %% [markdown]
# # Create the rename map

# %%
model_institude_df = cat.df.drop_duplicates(subset='source_id')[['source_id','institution_id']]

coord_rename_map = {}

for index, row in model_institude_df.iterrows():

    ds = dset_dict[f'CMIP.{row.institution_id}.{row.source_id}.historical.Omon.gn']
    
    coord_rename_map.update(make_rename_map(ds,model=row.source_id))

coord_rename_map
# Out:
# {'AWI-CM-1-1-MR': {'lat': 'latitude', 'lon': 'longitude', 'depth': 'lev'},
#  'BCC-CSM2-MR': {'lev': 'lev'},
#  'BCC-ESM1': {'lev': 'lev'},
#  'CAMS-CSM1-0': {'latitude': 'latitude',
#   'longitude': 'longitude',
#   'lev': 'lev'},
#  'FGOALS-f3-L': {'latitude': 'latitude',
#   'longitude': 'longitude',
#   'lev': 'lev'},
#  'CanESM5': {'latitude': 'latitude', 'longitude': 'longitude', 'lev': 'lev'},
#  'CNRM-CM6-1': {'lat': 'latitude', 'lon': 'longitude', 'lev': 'lev'},
#  'CNRM-ESM2-1': {'lat': 'latitude', 'lon': 'longitude', 'lev': 'lev'},
#  'EC-Earth3-Veg': {'latitude': 'latitude',
#   'longitude': 'longitude',
#   'lev': 'lev'},
#  'IPSL-CM6A-LR': {'nav_lat': 'latitude',
#   'nav_lon': 'longitude',
#   'olevel': 'lev'},
#  'MIROC-ES2L': {'latitude': 'latitude',
#   'longitude': 'longitude',
#   'lev': 'lev'},
#  'MIROC6': {'latitude': 'latitude', 'longitude': 'longitude', 'lev': 'lev'},
#  'HadGEM3-GC31-LL': {'latitude': 'latitude',
#   'longitude': 'longitude',
#   'lev': 'lev'},
#  'UKESM1-0-LL': {'latitude': 'latitude',
#   'longitude': 'longitude',
#   'lev': 'lev'},
#  'GISS-E2-1-G-CC': {'lat': 'latitude', 'lon': 'longitude', 'lev': 'lev'},
#  'GISS-E2-1-G': {'lat': 'latitude', 'lon': 'longitude', 'lev': 'lev'},
#  'CESM2': {'lat': 'latitude', 'lon': 'longitude', 'lev': 'lev'},
#  'NorCPM1': {'latitude': 'latitude', 'longitude': 'longitude', 'rho': 'lev'},
#  'GFDL-ESM4': {'lat': 'latitude', 'lon': 'longitude', 'lev': 'lev'},
#  'NESM3': {'latitude': 'latitude', 'longitude': 'longitude', 'lev': 'lev'},
#  'SAM0-UNICON': {'latitude': 'latitude',
#   'longitude': 'longitude',
#   'lev': 'lev'},
#  'MCM-UA-1-0': {'latitude': 'latitude',
#   'longitude': 'longitude',
#   'lev': 'lev'}}

# %% [markdown]
# # Test to see if it works

# %%
for index, row in model_institude_df.iterrows():

    ds = dset_dict[f'CMIP.{row.institution_id}.{row.source_id}.historical.Omon.gn']
    
    model = row.source_id
    
    print('______________________________________________')
    print(f'{model}\n')
    ds = ds.rename(coord_rename_map[model])
    ds.attrs = ''
    print(f'{ds[["latitude","longitude","lev"]]}\n')
# Out:
# ______________________________________________
# AWI-CM-1-1-MR
#
# <xarray.Dataset>
# Dimensions:    (lev: 46, ncells: 830305)
# Coordinates:
#   * lev        (lev) float64 -0.0 10.0 20.0 30.0 ... 5.4e+03 5.65e+03 5.9e+03
# Dimensions without coordinates: ncells
# Data variables:
#     latitude   (ncells) float64 dask.array<chunksize=(830305,), meta=np.ndarray>
#     longitude  (ncells) float64 dask.array<chunksize=(830305,), meta=np.ndarray>
#
# ______________________________________________
# BCC-CSM2-MR
#
# <xarray.Dataset>
# Dimensions:    (lat: 232, lev: 40, lon: 360)
# Coordinates:
#   * lev        (lev) float64 5.0 15.0 25.0 ... 4.289e+03 4.807e+03 5.334e+03
#   * lon        (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#   * lat        (lat) float64 -81.5 -80.5 -79.5 -78.5 ... 86.5 87.5 88.5 89.5
# Data variables:
#     latitude   (lat, lon) float32 dask.array<chunksize=(232, 360), meta=np.ndarray>
#     longitude  (lat, lon) float32 dask.array<chunksize=(232, 360), meta=np.ndarray>
#
# ______________________________________________
# BCC-ESM1
#
# <xarray.Dataset>
# Dimensions:    (lat: 232, lev: 40, lon: 360)
# Coordinates:
#   * lev        (lev) float64 5.0 15.0 25.0 ... 4.289e+03 4.807e+03 5.334e+03
#   * lon        (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#   * lat        (lat) float64 -81.5 -80.5 -79.5 -78.5 ... 86.5 87.5 88.5 89.5
# Data variables:
#     latitude   (lat, lon) float32 dask.array<chunksize=(232, 360), meta=np.ndarray>
#     longitude  (lat, lon) float32 dask.array<chunksize=(232, 360), meta=np.ndarray>
#
# ______________________________________________
# CAMS-CSM1-0
#
# <xarray.Dataset>
# Dimensions:    (i: 360, j: 200, lev: 50)
# Coordinates:
#   * lev        (lev) float64 5.0 15.0 25.0 35.0 ... 4.587e+03 4.95e+03 5.316e+03
#   * j          (j) int32 1 2 3 4 5 6 7 8 9 ... 193 194 195 196 197 198 199 200
#   * i          (i) int32 1 2 3 4 5 6 7 8 9 ... 353 354 355 356 357 358 359 360
# Data variables:
#     latitude   (j, i) float32 dask.array<chunksize=(200, 360), meta=np.ndarray>
#     longitude  (j, i) float32 dask.array<chunksize=(200, 360), meta=np.ndarray>
#
# ______________________________________________
# FGOALS-f3-L
#
# <xarray.Dataset>
# Dimensions:    (i: 360, j: 218, lev: 30)
# Coordinates:
#   * lev        (lev) float64 5.0 15.0 25.0 ... 3.856e+03 4.538e+03 5.244e+03
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 210 211 212 213 214 215 216 217
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 352 353 354 355 356 357 358 359
# Data variables:
#     latitude   (j, i) float64 dask.array<chunksize=(218, 360), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(218, 360), meta=np.ndarray>
#
# ______________________________________________
# CanESM5
#
# <xarray.Dataset>
# Dimensions:    (i: 360, j: 291, lev: 45)
# Coordinates:
#   * lev        (lev) float64 3.047 9.454 16.36 ... 5.126e+03 5.375e+03 5.625e+03
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 283 284 285 286 287 288 289 290
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 352 353 354 355 356 357 358 359
# Data variables:
#     latitude   (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     longitude  (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#
# ______________________________________________
# CNRM-CM6-1
#
# <xarray.Dataset>
# Dimensions:    (lev: 75, x: 362, y: 294)
# Coordinates:
#   * lev        (lev) float64 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
# Dimensions without coordinates: x, y
# Data variables:
#     latitude   (y, x) float64 dask.array<chunksize=(294, 362), meta=np.ndarray>
#     longitude  (y, x) float64 dask.array<chunksize=(294, 362), meta=np.ndarray>
#
# ______________________________________________
# CNRM-ESM2-1
#
# <xarray.Dataset>
# Dimensions:    (lev: 75, x: 362, y: 294)
# Coordinates:
#   * lev        (lev) float64 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
# Dimensions without coordinates: x, y
# Data variables:
#     latitude   (y, x) float64 dask.array<chunksize=(294, 362), meta=np.ndarray>
#     longitude  (y, x) float64 dask.array<chunksize=(294, 362), meta=np.ndarray>
#
# ______________________________________________
# EC-Earth3-Veg
#
# <xarray.Dataset>
# Dimensions:    (i: 362, j: 292, lev: 75)
# Coordinates:
#   * lev        (lev) float64 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * j          (j) int32 1 2 3 4 5 6 7 8 9 ... 285 286 287 288 289 290 291 292
#   * i          (i) int32 1 2 3 4 5 6 7 8 9 ... 355 356 357 358 359 360 361 362
# Data variables:
#     latitude   (j, i) float64 dask.array<chunksize=(292, 362), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(292, 362), meta=np.ndarray>
#
# ______________________________________________
# IPSL-CM6A-LR
#
# <xarray.Dataset>
# Dimensions:    (lev: 75, x: 362, y: 332)
# Coordinates:
#   * lev        (lev) float32 0.50576 1.5558553 2.6676817 ... 5698.0605 5902.0576
# Dimensions without coordinates: x, y
# Data variables:
#     latitude   (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     longitude  (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#
# ______________________________________________
# MIROC-ES2L
#
# <xarray.Dataset>
# Dimensions:    (lev: 63, x: 360, y: 256)
# Coordinates:
#   * lev        (lev) float64 1.0 3.5 7.0 11.0 ... 6.24e+03 6.87e+03 7.25e+03
#   * x          (x) float64 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * y          (y) float64 -88.0 -85.75 -85.25 -84.75 ... 148.6 150.5 152.4
# Data variables:
#     latitude   (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     longitude  (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#
# ______________________________________________
# MIROC6
#
# <xarray.Dataset>
# Dimensions:    (lev: 63, x: 360, y: 256)
# Coordinates:
#   * lev        (lev) float64 1.0 3.5 7.0 11.0 ... 6.24e+03 6.87e+03 7.25e+03
#   * x          (x) float64 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * y          (y) float64 -88.0 -85.75 -85.25 -84.75 ... 148.6 150.5 152.4
# Data variables:
#     latitude   (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     longitude  (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#
# ______________________________________________
# HadGEM3-GC31-LL
#
# <xarray.Dataset>
# Dimensions:    (i: 360, j: 330, lev: 75)
# Coordinates:
#   * lev        (lev) float64 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 322 323 324 325 326 327 328 329
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 352 353 354 355 356 357 358 359
# Data variables:
#     latitude   (j, i) float32 dask.array<chunksize=(330, 360), meta=np.ndarray>
#     longitude  (j, i) float32 dask.array<chunksize=(330, 360), meta=np.ndarray>
#
# ______________________________________________
# UKESM1-0-LL
#
# <xarray.Dataset>
# Dimensions:    (i: 360, j: 330, lev: 75)
# Coordinates:
#   * lev        (lev) float64 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 322 323 324 325 326 327 328 329
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 352 353 354 355 356 357 358 359
# Data variables:
#     latitude   (j, i) float32 dask.array<chunksize=(330, 360), meta=np.ndarray>
#     longitude  (j, i) float32 dask.array<chunksize=(330, 360), meta=np.ndarray>
#
# ______________________________________________
# GISS-E2-1-G-CC
#
# <xarray.Dataset>
# Dimensions:    (latitude: 180, lev: 40, longitude: 288)
# Coordinates:
#   * latitude   (latitude) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * longitude  (longitude) float64 0.625 1.875 3.125 4.375 ... 356.9 358.1 359.4
#   * lev        (lev) float64 5.0 16.0 29.0 ... 4.453e+03 4.675e+03 4.897e+03
# Data variables:
#     *empty*
#
# ______________________________________________
# GISS-E2-1-G
#
# <xarray.Dataset>
# Dimensions:    (latitude: 180, lev: 40, longitude: 288)
# Coordinates:
#   * latitude   (latitude) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * longitude  (longitude) float64 0.625 1.875 3.125 4.375 ... 356.9 358.1 359.4
#   * lev        (lev) float64 5.0 16.0 29.0 ... 4.453e+03 4.675e+03 4.897e+03
# Data variables:
#     *empty*
#
# ______________________________________________
# CESM2
#
# <xarray.Dataset>
# Dimensions:    (lev: 60, nlat: 384, nlon: 320)
# Coordinates:
#   * lev        (lev) float64 500.0 1.5e+03 2.5e+03 ... 5.125e+05 5.375e+05
#   * nlon       (nlon) int32 1 2 3 4 5 6 7 8 ... 313 314 315 316 317 318 319 320
#   * nlat       (nlat) int32 1 2 3 4 5 6 7 8 ... 377 378 379 380 381 382 383 384
# Data variables:
#     latitude   (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     longitude  (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#
# ______________________________________________
# NorCPM1
#
# <xarray.Dataset>
# Dimensions:    (i: 320, j: 384, lev: 53)
# Coordinates:
#   * lev        (lev) float64 1.027e+03 1.028e+03 ... 1.038e+03 1.038e+03
#   * j          (j) int32 1 2 3 4 5 6 7 8 9 ... 377 378 379 380 381 382 383 384
#   * i          (i) int32 1 2 3 4 5 6 7 8 9 ... 313 314 315 316 317 318 319 320
# Data variables:
#     latitude   (j, i) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#
# ______________________________________________
# GFDL-ESM4
#
# <xarray.Dataset>
# Dimensions:    (lev: 35, x: 720, y: 576)
# Coordinates:
#   * lev        (lev) float64 2.5 10.0 20.0 32.5 ... 5e+03 5.5e+03 6e+03 6.5e+03
#   * x          (x) float64 -299.8 -299.2 -298.8 -298.2 ... 58.75 59.25 59.75
#   * y          (y) float64 -77.91 -77.72 -77.54 -77.36 ... 89.47 89.68 89.89
# Data variables:
#     latitude   (y, x) float32 dask.array<chunksize=(576, 720), meta=np.ndarray>
#     longitude  (y, x) float32 dask.array<chunksize=(576, 720), meta=np.ndarray>
#
# ______________________________________________
# NESM3
#
# <xarray.Dataset>
# Dimensions:    (i: 362, j: 292, lev: 46)
# Coordinates:
#   * lev        (lev) float64 3.047 9.454 16.36 ... 5.375e+03 5.625e+03 5.875e+03
#   * j          (j) int32 1 2 3 4 5 6 7 8 9 ... 285 286 287 288 289 290 291 292
#   * i          (i) int32 1 2 3 4 5 6 7 8 9 ... 355 356 357 358 359 360 361 362
# Data variables:
#     latitude   (j, i) float32 dask.array<chunksize=(292, 362), meta=np.ndarray>
#     longitude  (j, i) float32 dask.array<chunksize=(292, 362), meta=np.ndarray>
#
# ______________________________________________
# SAM0-UNICON
#
# <xarray.Dataset>
# Dimensions:    (i: 320, j: 384, lev: 60)
# Coordinates:
#   * lev        (lev) float64 5.0 15.0 25.0 ... 4.875e+03 5.125e+03 5.375e+03
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 376 377 378 379 380 381 382 383
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 312 313 314 315 316 317 318 319
# Data variables:
#     latitude   (j, i) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#
# ______________________________________________
# MCM-UA-1-0
#
# <xarray.Dataset>
# Dimensions:    (latitude: 80, lev: 18, longitude: 192)
# Coordinates:
#   * latitude   (latitude) float64 -88.63 -86.13 -83.88 ... 83.88 86.13 88.63
#   * longitude  (longitude) float64 -0.9375 0.9375 2.812 ... 353.4 355.3 357.2
#   * lev        (lev) float64 20.0 61.71 107.8 ... 3.373e+03 3.999e+03 4.662e+03
# Data variables:
#     *empty*
